# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = ['Python', 'C++', 'Java', 'JavaScript']
y = [10, 12, 7, 15]
plt.bar(x, y, color='green', align="edge", width=0.5, edgecolor="black", linewidth=6)
plt.show()

# %%
ic =list(range(1, 10, 3))
ic
# Out:
# [1, 4, 7]
