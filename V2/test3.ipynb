# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
def func(x):
    return np.exp(-x)

# %%
def func2(x):
    return np.exp(-x) - x

# %%
xi, xi1 = 0, 0
# x, y = np.array(()), np.array(())
ea = 0
et = 0

print("i\tx_i\tea")

x = np.linspace(0, 1, 10)
y = x

# plt.figure(1)
plt.plot(x, y)

# plt.figure(2)
for i in range(11):
    plt.scatter(xi, xi1)
    plt.plot(xi1, 0)
    # plt.text(xi, xi1, f"({xi}, {xi1})", ha = "left", va="bottom")
    if i ==  0:
        print(f"{i}\t{xi:.4f}\t----")
    else:
        xi1 = func(xi)
        ea = abs((xi1 - xi) / xi1) * 100
        print(f"{i}\t{xi1:.4f}\t{ea:.4f}")
    xi = xi1
plt.show()
# Out:
# i	x_i	ea
# 0	0.0000	----
# 1	1.0000	100.0000
# 2	0.3679	171.8282
# 3	0.6922	46.8536
# 4	0.5005	38.3091
# 5	0.6062	17.4468
# 6	0.5454	11.1566
# 7	0.5796	5.9034
# 8	0.5601	3.4809
# 9	0.5711	1.9308
# 10	0.5649	1.1089

# %%
len(x)
